# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# Buat dataset sederhana
np.random.seed(0)
X = 4 * np.random.rand(100, 1)
y = 5 + 7 * X + np.random.randn(100, 1)

# Plot dataset
# Plot predictions vs actual
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, label='Predicted')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Actual vs Predicted')
plt.legend()
plt.show()

# Inisialisasi model regresi linear
model = LinearRegression()

# Latih model menggunakan data
model.fit(X, y)

# Prediksi nilai y
y_pred = model.predict(X)

# Koefisien (slope) dan intersep dari model
slope = model.coef_[0][0]
intercept = model.intercept_[0]

# Evaluasi model
r2 = r2_score(y, y_pred)
rmse = np.sqrt(mean_squared_error(y, y_pred))
mae = mean_absolute_error(y, y_pred)
mse = mean_squared_error(y, y_pred)
mape = np.mean(np.abs((y - y_pred) / y)) * 100

print("========== Results ==========")
print("Koefisien (slope):", slope)
print("Intersep:", intercept)
print("R-squared (R²):", r2)
print("Root Mean Squared Error (RMSE):", rmse)
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# ========== Results ==========
# Koefisien (slope): 6.984233755350511
# Intersep: 5.222151077447226
# R-squared (R²): 0.9849319087852917
# Root Mean Squared Error (RMSE): 0.9962121504602562
# Mean Absolute Error (MAE): 0.8492581983239291
# Mean Squared Error (MSE): 0.9924386487246482
# Mean Absolute Percentage Error (MAPE): 5.917218219412907
